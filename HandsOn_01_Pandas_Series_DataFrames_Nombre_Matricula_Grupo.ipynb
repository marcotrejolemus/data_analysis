# %% [markdown]
# Facultad de Contaduria Pública y Administración / UANL / Análisis de Datos 2024 / Profesor MSI Marco Trejo

# %% [markdown]
# ## <span style='font-family:Times New Roman'><font color="darkblue"> HANDS ON 01 Operaciones Básicas con Pandas</font> </span>

# %% [markdown]
#  Importar, Crear y editar un Dataset simple para operaciones básicas como filtrado, agrupación y ordenamiento de datos.

# %% [markdown]
# 1.- Importar librerias

# %%
#importa las siguientes librerias: pandas y numpy y crea las variables respectivas: pd y np y presiona control + enter para ejecutar

#Ayuda: import (nombre de libreria) (variable)

Coloca tu linea de codigo aqui

# %% [markdown]
# 2.- Declara y Crea 6 series: nombre, apellido_paterno, apellido_materno, salario, telefono, numEmpleadoID,FechaCreacion

# %%
#utilizando la variable pd crea una serie llamada nombre y agrega 5 valores de texto
# Ayuda nombre = pd.Series(['Marco','Juan','Adrian','Carlos','Gisel'])
Coloca tu linea de codigo aqui

#utilizando la variable pd crea una serie llamada apellido_paterno y agrega 5 valores de texto
Coloca tu linea de codigo aqui

#utilizando la variable pd crea una serie llamada apellido_materno y agrega 5 valores de texto
Coloca tu linea de codigo aqui

#utilizando la variable pd crea una serie llamada salario y agrega 5 valores numericos enteros
Coloca tu linea de codigo aqui

#utilizando la variable pd crea una serie llamada telefono y agrega 5 valores numericos enteros
Coloca tu linea de codigo aqui

#utilizando la variable pd crea una serie llamada numEmpleadoID y agrega 5 valores numericos enteros
Coloca tu linea de codigo aqui

#utilizando la variable pd crea una serie llamada fechaCreacion y agrega 5 valores numericos enteros
Coloca tu linea de codigo aqui

# presiona control + enter para ejecutar

# %% [markdown]
# Visualiza la Serie nombre

# %%
# coloca la serie nombre y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza la Serie apellido paterno

# %%
# coloca la serie apellido_paterno y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza la Serie apellido materno

# %%
# coloca la serie apellido_materno y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza la Serie salario

# %%
# coloca la serie salario y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza la Serie telefono

# %%
# coloca la serie telefono y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza la Serie NumEmpleadoID

# %%
# coloca la serie numEmpleadoID y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza la Serie fechaCreacion

# %%
# coloca la serie fechaCreacion y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza solo los valores (datos) del objeto **Series**:

# %%
# coloca la serie nombre separada por un punto . y la palabra values y presiona control + enter
# Ayuda: nombre = pd.Series(['Marco','Juan','Adrian','Carlos','Gisel'])
Coloca tu linea de codigo aqui

# %%
# coloca la serie apellido_paterno separada por un punto . y la palabra values y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie apellido_materno separada por un punto . y la palabra values y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie salario separada por un punto . y la palabra values y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie telefono separada por un punto . y la palabra values y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie apellido_paterno separada por un punto . y la palabra values y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie fechaCreacion separada por un punto . y la palabra values y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Visualiza solo los indices (index) del objeto **Series**:

# %%
# coloca la serie nombre separada por un punto . y index.tolist() y presiona control + enter
#Ayuda: nombre.index.tolist()
Coloca tu linea de codigo aqui

# %%
# coloca la serie apellido_paterno separada por un punto . y index.tolist() y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie apellido_materno separada por un punto . y index.tolist() y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie salario separada por un punto . y index.tolist() y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie telefono separada por un punto . y index.tolist() y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie numEmpleadoID separada por un punto . y index.tolist() y presiona control + enter
Coloca tu linea de codigo aqui

# %%
# coloca la serie fechaCreacion separada por un punto . y index.tolist() y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Encontrar el valor máximo y mínimo del objeto **Series**: salario

# %%
# coloca la serie salario separada por un punto . y la palabra max() y presiona control + enter
#Ayuda salario.max()
Coloca tu linea de codigo aqui

# %%
# coloca la serie salario separada por un punto . y la palabra min() y presiona control + enter
Coloca tu linea de codigo aqui

# %% [markdown]
# Encontrar las medidas de tendencia central: media, mediana y moda (mean,median,mode) para el objeto salario **Series**: salario

# %%
# coloca la serie salario separada por un punto . y la palabra mean()
#Ayuda salario.mean()
Coloca tu linea de codigo aqui

# %%
# coloca la serie salario separada por un punto . y la palabra median()
Coloca tu linea de codigo aqui

# %%
# coloca la serie salario separada por un punto . y la palabra mode()
Coloca tu linea de codigo aqui

# %% [markdown]
# Crear un objeto **DataFrame** a partir de listas de Python:

# %% [markdown]
# Crea el objeto DataFrame: datos_de_los_empleados

# %%
# utilizaremos 5 de las listas ya creadas anteriormenete comoo Series: nombre, apellido_paterno, apellido_materno, salario, numEmpleadoID, fechaCreacion
# Crea el objeto datos_de_los_empleados agrega las listas creadas y su nombre: nombre, apellido_paterno, apellido_materno, salario, numEmpleadoID, fechaCreacion
# Ayuda datos_de_los_empleados = {'Nombre': nombre, 'Apellido Paterno': apellido_paterno, 'Apellido Materno': apellido_materno, 'Salario': salario, 'Num. Tel':telefono, 'EmpleadoID':numEmpleadoID, 'FechaCreacion':fechaCreacion}

Coloca tu linea de codigo aqui

# %%
# Ayuda en este ejemplo se crea producto de tipo DataFrame que utiliza data_de_los_productos
# producto = pd.DataFrame(data_de_los_productos)
# Ahora crea el objeto llamado: demp .... que sea de tipo DataFrame que utilice data_list_employee

Coloca tu linea de codigo aqui

# %%
# Visualiza el DataFrame demp
#Ayuda coloca el nombre del objeto demp y presiona control + enter

# %% [markdown]
# Visualiza los indices del DataFrame

# %%
#coloca el id del DataFrame demp separado por un punto . y la palabra index.tolist()

Coloca tu linea de codigo aqui

# %% [markdown]
# Encuentra el valor máximo y mínimo en un objeto **DataFrame**:

# %%
# coloca el objeto DataFrama llamado demp separado por un punto . y la palabra min()

Coloca tu linea de codigo aqui

# %% [markdown]
# ##<font color=firebrick>4 Pasos para Importar datos de archivos de Excel con pandas </font>

# %%
# Primero debemos colocar el archivo CSV de nuestra preferencia en nuestro Google Drive puedes descargar usar cualquier fuente CSV ya sea crearlos manualmente
# Opcional buscar de la pagina https://www.tableau.com/es-es/blog/public-data-sets-102221

# Ver imagen abajo: en este caso arrastre hacia la raiz del Google Drive el archivo nations.csv

# Ahora te toca CREAR o DESCARGAR un archivo CSV y SUBIRLO a tu Google Drive en el directorio raiz
# Ayuda (Puedes usar el archivo nation.csv que se envio en el TEAMS) y realizar el paso de subir el archivo como se muestra en la siguiente imagen

# %% [markdown]
# Primero: Colocar el archivo CSV en nuestro Google drive raiz (My Drive) para tenerlo disponible y poder ejecutar una lectura de los registros que contiene internamente el archivo.
#
# ![UploadCSV.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Segundo: Asignar la localización del archivo a una variable. Esta represantación de la localización del archivo es a lo que llamamos filepath.

# %%
# Segundo debemos conectarnos a nuestro drive, ya sea en la barra lateral izquierda o con los comandos siguientes.
from google.colab import drive
drive.mount('/content/drive/')

# %% [markdown]
# Tercero: Después nos debemos situar en la dirección donte esta el archivo o en su defecto darle el path completo de la localización del archivo

# %%
# Tercero: Se importa la librería pandas, para el manejo de datos.
# Se le asigna el alias "pd", que es el estándar de
# codificación de la comunidad.

import pandas as pd

# Como los datos están en un archivo CSV, en lugar del nombre de
# archivo se utiliza la URL para acceso raw a los datos,
# que es lo mismo que leer un archivo que tenemos físicamente
# en nuestro equipo. Se declara una variable para almacenar la URL.

# Colocar su ejemplo a continuacion y crear la variable para almacenar el archivo CSV en este caso datos_naciones_csv
## Crea tu propia variable
# Ayuda: si utilizas el archivo nations.csv utiliza la siguiente instruccion
# datos_naciones_csv = '/content/drive/MyDrive/nations.csv'

Coloca tu linea de codigo aqui

# Se cargan los datos del archivo en la variable "datos_naciones_csv" a un
# DataFrame de pandas llamado "naciones", usando la función
# pd.read_csv(), usando como nombre de archivo la variable
# que almacena la URL para acceder a los datos.

## Crea tu propio DataFrame
# Ayuda: si utilizas el archivo nations.csv utiliza la siguiente instruccion
# naciones = pd.read_csv(datos_naciones_csv, encoding='latin-1')

Coloca tu linea de codigo aqui

# %% [markdown]
# Cuarto: Visualizar los datos del DataFrame generado desde el CSV

# %%
# Cuarto: visualizar datos del DataFrame colocando el nombre del dataframe
## Visualiza tu propio DataFrame
# Ayuda: si utilizas el archivo nations.csv utiliza la siguiente instruccion
# naciones

Coloca tu linea de codigo aqui

# %% [markdown]
# ##<font color=firebrick>A partir de AQUI... AHORA es tu turno para intentar con NUEVOS archivos CSV sigue los pasos del 1 al 4 para importar tu archivo CSV </font>

# %%
# Primero debemos colocar el archivo CSV de nuestra preferencia en nuestro Google Drive puedes descargar usar cualquier fuente CSV ya sea crearlos manualmente
# Opcional buscar de la pagina https://www.tableau.com/es-es/blog/public-data-sets-102221

# Ver imagen abajo: en este caso arrastre hacia la raiz del Google Drive el archivo nations.csv

# Ahora te toca CREAR o DESCARGAR un archivo CSV y SUBIRLO a tu Google Drive en el directorio raiz
# Ayuda realizar el paso de subir el archivo como se muestra en la siguiente imagen

# %% [markdown]
# Primero: Colocar el archivo CSV en nuestro Google drive raiz (My Drive) para tenerlo disponible y poder ejecutar una lectura de los registros que contiene internamente el archivo.
#
# ![UploadCSV.jpg](data:image/jpeg;base64,...)

# %%
# Segundo debemos conectarnos a nuestro drive, ya sea en la barra lateral izquierda o con los comandos siguientes.
from google.colab import drive
drive.mount('/content/drive/')

# %%
# Tercero: Se importa la librería pandas, para el manejo de datos.
# Se le asigna el alias "pd", que es el estándar de
# codificación de la comunidad.

import pandas as pd

# Como los datos están en un archivo CSV, en lugar del nombre de
# archivo se utiliza la URL para acceso raw a los datos,
# que es lo mismo que leer un archivo que tenemos físicamente
# en nuestro equipo. Se declara una variable para almacenar la URL.
# Crear la variable para almacenar el archivo CSV en este caso: ejemplos: datos_airline-safety_csv, fifa_countries_audience_csv
# datos_nombrevariable_csv = '/content/drive/MyDrive/nombre_archivo.csv'
# Ayuda: si descargaste nations.csv utiliza datos_naciones_csv = '/content/drive/MyDrive/nations.csv'

Coloca tu linea de codigo aqui

# Se cargan los datos del archivo en la variable "datos_naciones_csv" a un
# DataFrame de pandas llamado "naciones", usando la función
# pd.read_csv(), usando como nombre de archivo la variable
# que almacena la URL para acceder a los datos.
# variableDataFrame = pd.read_csv( datos_nombrevariable_csv, encoding='latin-1')
# Ayuda: si descargaste nations.csv utiliza naciones = pd.read_csv(datos_naciones_csv, encoding='latin-1')

Coloca tu linea de codigo aqui

# %%
# Cuarto: visualizar datos del DataFrame colocando el nombre del dataframe
# variableDataFrame
# Ayuda: si descargaste nations.csv utiliza el nombre del DataFrame: naciones

# %% [markdown]
# ## Visualización de datos de un DataFrame

# %%
# Ver las primeras filas del DataFrame nombre del DataFrame separado por un punto y la palabra head() ejemplo: titanic.head()
# Ayuda: si descargaste nations.csv utiliza el nombre del DataFrame: naciones.head()
Coloca tu linea de codigo aqui

# %%
# Ver las primeras 10 filas del DataFrame nombre del DataFrame separado por un punto y la palabra head(10) ejemplo: titanic.head(10)

Coloca tu linea de codigo aqui

# %%
# Ver las ultimas filas del DataFrame nombre del DataFrame separado por un punto y la palabra tail() ejemplo: titanic.tail()

Coloca tu linea de codigo aqui

# %%
# Ver la lista de columnas, con sus tipos  nombre del DataFrame separado por un punto y la palabra dtypes() ejemplo: titanic.dtypes
Coloca tu linea de codigo aqui

# %%
# Ver la lista de columnas, con tipos, y con filas sin nulos
# nombre del DataFrame separado por un punto y la palabra info() ejemplo: titanic.info()

Coloca tu linea de codigo aqui

# %%
# Ver la longitud del DataFrame ejemplo para ver la longitud del DataFrame titanic utilizar:  len(titanic)
Coloca tu linea de codigo aqui

# %%
# Ver el tamaño del conjunto de datos (filas x columnas) ejemplo para ver la el tamaño del DataFrame titanic utilizar : titanic.size

Coloca tu linea de codigo aqui

# %% [markdown]
# ##<font color=firebrick>Escribir en un archivo excel desde un DataFrame</font>

# %% [markdown]
# Supongamos que tenemos un DataFrame llamado titanic, y queremos guardar
# su estructura y sus datos en nuestra raiz de Google Drive un archivo llamado personas_titanic.xlsx, será como el siguiente ejemplo:
#
#   titanic.to_excel('/content/drive/MyDrive/personas_titanic.xlsx', index=False)

# %%
# Guarda el contenido del DataFrame en un archivo
# Excel, usando to_excel(), incluyendo el parámetro index=False, para no incluir el índice.
# Ayuda: datos_nations.to_excel('/content/drive/MyDrive/nations_excel_file.xlsx', index=False)

Coloca tu linea de codigo aqui

# %% [markdown]
# ##<font color=firebrick>Escribir en un archivo CSV desde un DataFrame</font>

# %% [markdown]
# Supongamos que tenemos un DataFrame llamado titanic, y queremos guardar
# su estructura y sus datos en nuestra raiz de Google Drive un archivo llamado personas_titanic.csv, será así.
#
# titanic.to_csv('/content/drive/MyDrive/personas_titanic.csv', index=False)

# %%
# Guarda el contenido del DataFrame en un archivo
# CSV, usando to_csv(), incluyendo el parámetro index, para
# no incluir el índice. Ejemplo: titanic.to_csv('/content/drive/MyDrive/personas_titanic.csv', index=False)

Coloca tu linea de codigo aqui

# %% [markdown]
# ##<font color=firebrick>Integrar dos DataFrames en un Libro en Excel con dos hojas</font>

# %% [markdown]
# Supongamos que queremos generar dos Libros de Excel.
# 1. Un Libro de Excel llamado nations_datos_actualizados.xlsx, que contiene
# una hoja llamado datos, que contiene todos los datos, sin incluir el
# índice.
#
# 2. Un Libro de Excel llamado nations_datos_actualizados.xlsx, que:
# a. Contiene una hoja llamado europe_region_literacy, que contiene country, region,life,literacy de las personas que son de las Americas, region = "Americas".
# b. Contiene una hoja llamado europe_region_literacy, que contiene country, region,life,literacy de las personas que son de Europa, region = "Europe".

# %%
# Se genera el primer Libro de Excel, llamado datos_actualizados.xlsx
# No se incluye el índice. El nombre de la hoja será datos.
# Ayuda para el csv nations utiliza lo siguiente: nations.to_excel('nations_datos_actualizados.xlsx', index=False, sheet_name='datos' )

Coloca tu linea de codigo aqui

# Recuperar columnas: se recuperan las columnas country, region,life,literacy de las personas que son de las americas.
# Ayuda para el csv nations utiliza las siguientes lineas:
# americas_region_literacy  = nations[['country','region', 'life','literacy']][(nations['region']=="Americas")]
# americas_region_literacy

Coloca tu linea de codigo aqui
Coloca tu linea de codigo aqui

# %%
# Se recuperan las columnas country, region,life,literacy de las personas que son de Europa.
# Ayuda para el csv nations utiliza las siguientes lineas:
# europe_region_literacy  = nations[['country','region', 'life','literacy']][(nations['region']=="Europe")]
# europe_region_literacy

Coloca tu linea de codigo aqui
Coloca tu linea de codigo aqui

# %%
# Generar una hoja de excel por cada DataFrame se genera una Hoja de Excel por cada DataFrame, y se
# almacenan en un mismo libro (nations_datos_actualizados.xlsx).
# Ayuda si usaste el csv nations utiliza las siguientes 3 lineas:
# with pd.ExcelWriter('/content/drive/MyDrive/nations_datos_actualizados.xlsx') as flujo:
# americas_region_literacy.to_excel(flujo, sheet_name='americas', index=False)
# europe_region_literacy.to_excel(flujo, sheet_name='europe', index=False)

Coloca tu linea de codigo aqui
Coloca tu linea de codigo aqui
Coloca tu linea de codigo aqui

# %% [markdown]
# Se revisa la creacion del archivo excel nations_datos_actualizados.xlsx con las dos pestañas Americas y Europe

# %% [markdown]
# ![datos_actualizados.jpg](data:image/jpeg;base64,...)![datos_actualizados_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##<font color=firebrick>Trabajo con columnas</font>

# %% [markdown]
# Las tareas por realizar son:
# 1. Eliminar columnas no requeridas usando drop().
# 2. Eliminar filas duplicadas usando drop_duplicates().
# 3. Eliminar filas con datos vacíos usando dropna().
# a. Eliminar las filas con todas las columnas vacías.
# b. Eliminar las filas con 3 o más columnas vacías.
# 4. Crear un indicador ficticio.
# 5. Verificar unicidad de columnas usando duplicated().
# 6. Verificar la unicidad de un campo de identidad.
# a. Verificar la unicidad de un campo categórico.
# b. Verificar la unicidad de un campo con vacíos.

# %%
# Datos base
# import pandas as pd
# pasajeros_titanic_csv='https://raw.githubusercontent.com/AprendaPracticando/AnaliticaPythonR1/main/data/pasajeros_titanic.csv'
# titanic = pd.read_csv(pasajeros_titanic_csv)
# titanic.drop(columns=['boleto','tarifa','cabina','embarque','residencias'],inplace=True)
# titanic['identificador']=pd.Series(range(10000, len(titanic)+10000))

# Ayuda: import pandas ejemplo:
import pandas as pd


# Crear la variable para almacenar el archivo CSV en este caso: ejemplos: datos_airline-safety_csv, fifa_countries_audience_csv
# Ayuda: ejemplo datos_nations_csv = '/content/drive/MyDrive/nations.csv'
inserte codigo aqui

# Se cargan los datos del archivo en la variable "datos_naciones_csv" a un
# DataFrame de pandas llamado "nations", usando la función
# pd.read_csv(), usando como nombre de archivo la variable
# que almacena la URL para acceder a los datos.
# Ayuda si utilizaste el csv nations.csv utiliza lo siguiente:
# nations = pd.read_csv( datos_nations_csv, encoding='latin-1')

inserte codigo aqui

# # Quitar columnas utilizando drop ejemplo drop titanic.drop(columns=['boleto','tarifa','cabina','embarque','residencias'],inplace=True)
# Ayuda si utilizaste el csv nations.csv utiliza lo siguiente:
# nations.drop (columns=['gdp','adfert','femlab','co2','gini'], inplace=True)

inserte codigo aqui

# %% [markdown]
# Agregar una COLUMNA de tipo secuencia que empiece del 10000 y se incremente de 1 en 1

# %%
# Agregar columna de tipo secuencia como identificador ejemplo titanic['identificador']=pd.Series(range(10000,len(titanic)+10000))
# Ayuda si utilizaste el csv nations.csv utiliza lo siguiente:
# nations['identificador']=pd.Series(range(10000,len(nations)+10000))
inserte codigo aqui

# %%
#  Ver DataFrame
# ejemplo colocar el nombre: nations y presiona ctr + enter
inserte codigo aqui

# %% [markdown]
# ##<font color=firebrick>Ordenar los datos de un DataFrame</font>

# %%
# Genera una lista que contenga los nombres de columnas
# en el orden deseado.
# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo
# campos_ordenados=['country','region','school','chldmort','life','pop','urban','literacy','identificador']

inserte codigo aqui
# Recupera los campos en el orden especificado en la lista, y
# guárdalos en el mismo DataFrame origen. Dicho de otra forma,
# el DataFrame es la representación ordenada de sí mismo.
# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo
# nations=nations[campos_ordenados]
inserte codigo aqui

# Enumera los campos del DataFrame para comprobar el
# nuevo orden, usando dtypes.
# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo
# nations.dtypes
inserte codigo aqui

# %% [markdown]
# ##<font color=firebrick>Cambiar nombre de columnas en un DataFrame</font>

# %% [markdown]
# Se desean hacer los siguientes cambios de nombre de columna:
# 1. Los identificadores, requeridos o no requeridos, deben iniciar con
# id_.
# 2. Los datos de valor que indiquen cantidad deben iniciar con
# cantidad_.
# 3. Los categóricos numéricos y codificados, deben iniciar con clave_,
# porque requieren interpretación.
# 4. Se deben hacer precisiones de sustantivos. Por ejemplo, usar
# pasajeros resulta inexacto, pues la tripulación no era pasajera,
# entonces, lo adecuado sería hablar de personas.

# %%
# Genera un diccionario que contenga la equivalencia
# las llaves son los nombres de columna actuales, y los
# valores son los nombres que queremos asignar.

# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo:
# Las columnas que no sufren cambio no se ponen.Ver el siguiente ejemplo:
# nuevos_nombres = {
#      'country':'country_name',
#      'region':'region_name',
#      'school':'school_qty',
#      'chldmort':'chldmort_qty',
#      'life':'life_qty',
#      'pop':'pop_qty',
#      'urban':'urban_qty',
#      'literacy':'literacy_qty',
#      'identificador': 'id_record'
# }

inserte codigo aqui

# Renombra las columnas, usando rename(), aplica los
# cambios sobre el mismo DataFrame, usando inplace.
# titanic.rename(columns=nuevos_nombres,inplace=True)
# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo:
# ejemplo: nations.rename(columns=nuevos_nombres, inplace=True)

inserte codigo aqui

# Enumera los campos del DataFrame para comprobar los nuevos
# nombres, usando dtypes.
# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo
# nations.dtypes

inserte codigo aqui

# %%
# Ver DataFrame
# Ayuda si utilizaste el csv nations.csv utiliza el siguiente ejemplo
# nations

inserte codigo aqui

# %% [markdown]
# FIN DEL EJERCICIO
